# %% [markdown]
# 1. В переменной df находится датафрэйм. Ваша задача положить в переменную  df_shape строку с информацией сколько линий и столбцов он имеет в следующем виде: 'df has y rows and x columns', где y – число строк, а x – число колонок.

# %%
import pandas as pd

# %%
df = pd.DataFrame({'a':[1, 2, 3], 'b':['aaa', 'ccc', 'xxx']})
df
# Out:
#    a    b
# 0  1  aaa
# 1  2  ccc
# 2  3  xxx

# %%
template = 'df has {} rows and {} columns'
template.format(df.shape[0], df.shape[1])
# Out:
# 'df has 3 rows and 2 columns'

# %% [markdown]
# Альтернативный вариант

# %%
df_shape = f'df has {df.shape[0]} rows and {df.shape[1]} columns'
df_shape
# Out:
# 'df has 3 rows and 2 columns'

# %% [markdown]
# 2. Положите в переменную na_number серию, в которой для каждой колонки указано сколько ячеек содержат пропущенные значения.

# %%
import numpy as np

df = pd.DataFrame({'a':[1, np.nan, 3], 'age':['15', '33', '10']})
df
# Out:
#      a age
# 0  1.0  15
# 1  NaN  33
# 2  3.0  10

# %%
df.isna()
# Out:
#        a    age
# 0  False  False
# 1   True  False
# 2  False  False

# %%
na_number = df.isna().sum()

# %%
na_number
# Out:
# a      1
# age    0
# dtype: int64

# %% [markdown]
# 3. Сохраните в переменную df_types типы данных каждой колонки датафрэйма df.

# %%
df_types = df.dtypes

# %%
df_types
# Out:
# a      float64
# age     object
# dtype: object

# %% [markdown]
# 4. Внезапно оказалось, что в переменной age значения хранятся в виде строк! Поменяйте тип значений на целочисленный в этой колонке датафрэйма df.

# %%
df = df.astype({'age': 'int'})

# %%
df.dtypes
# Out:
# a      float64
# age      int32
# dtype: object

# %% [markdown]
# 5. Как выяснилось, для дальнейшего анализа нам не понадобятся колонки sex и age – удалите их из датафрэйма.

# %%
data = {
    'client_id': [1, 1, 3],
    'age': [23, 33, 59],
    'sex': ['F', 'F', 'M'],
    'wealth': ['high', 'medium', 'high']
}
df = pd.DataFrame(data)

# %%
df
# Out:
#    client_id  age sex  wealth
# 0          1   23   F    high
# 1          1   33   F  medium
# 2          3   59   M    high

# %%
df.drop(columns=['age', 'sex'], inplace=True)

# %%
df
# Out:
#    client_id  wealth
# 0          1    high
# 1          1  medium
# 2          3    high

# %% [markdown]
# 6. А теперь проверим, есть ли в нашей таблице df дубликаты по полю client_id – дропните все строки, в которых значения в колонке client_id повторяются.

# %%
df.drop_duplicates(subset=['client_id'], inplace=True)

# %%
df
# Out:
#    client_id wealth
# 0          1   high
# 2          3   high

# %% [markdown]
# 7. В списке numbers содержатся числа. Добавьте через цикл в список positive_numbers положительные числа из numbers. При этом, если вам попался 0, то нужно прекратить этот цикл.

# %%
numbers = [1, -2, 3, 0, -3, 2]
positive_numbers = []

for number in numbers:
    if number > 0:
        positive_numbers.append(number)
    elif number < 0:
        continue
    else:
        break
        
print('end')
# Out:
# end

# %%
positive_numbers
# Out:
# [1, 3]

# %% [markdown]
# 8. Продолжим анализ данных по поездкам. Теперь посмотрим на колонки со временем! Сохраните данные, находящиеся в папке (taxi_peru.csv), в переменную taxi, разделитель – ;. Затем приведите столбцы start_at, end_at, arrived_at к формату даты, используя pd.to_datetime(). Отфильтруйте данные и оставьте наблюдения со статусом заказа "asap" и "reserved" (start_type).

# %%
taxi = pd.read_csv('C:/Users/artyr/Desktop/Karpov_ML/taxi_peru.csv', sep=';')

# %%
taxi.head()
# Out:
#                          journey_id                           user_id  \
# 0  23a1406fc6a11d866e3c82f22eed4d4c  0e9af5bbf1edfe591b54ecdfd7e91e26
# 1  dd2af4715d0dc16eded53afc0e243577  a553c46e3a22fb9c326aeb3d72b3334e
# 2  dd91e131888064bf7df3ce08f3d4b4ad  a553c46e3a22fb9c326aeb3d72b3334e
# 3  dd2af4715d0dc16eded53afc0e2466d0  a553c46e3a22fb9c326aeb3d72b3334e
# 4  85b7eabcf5d84e42dc7629b7d27781af  56772d544fdfa589a020a1ff894a86f7
#
#                           driver_id                           taxi_id  \
# 0  583949a89a9ee17d19e3ca4f137b6b4c  b12f4f09c783e29fe0d0ea624530db56
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4  d665fb9f75ef5d9cd0fd89479380ba78  0accdd3aa5a322f4129fa20b53278c69
#
#         icon start_type             start_at     start_lat     start_lon  \
# ...

# %% [markdown]
# Вариант 1

# %%
taxi['start_at'] = pd.to_datetime(taxi.start_at) 
taxi['end_at'] = pd.to_datetime(taxi.start_at)
taxi['arrived_at'] = pd.to_datetime(taxi.start_at)

# %%
Вариант 2

# %%
taxi[['start_at', 'end_at', 'arrived_at']].apply(pd.to_datetime)
# Out:
#                  start_at              end_at          arrived_at
# 0     2010-11-16 16:44:00 2010-11-16 16:44:00 2010-11-16 16:44:00
# 1     2010-06-01 00:34:00 2010-06-01 00:34:00 2010-06-01 00:34:00
# 2     2010-05-31 05:01:00 2010-05-31 05:01:00 2010-05-31 05:01:00
# 3     2010-06-01 00:29:00 2010-06-01 00:29:00 2010-06-01 00:29:00
# 4     2010-09-11 23:55:00 2010-09-11 23:55:00 2010-09-11 23:55:00
# ...                   ...                 ...                 ...
# 23106 2010-07-31 13:15:00 2010-07-31 13:15:00 2010-07-31 13:15:00
# 23107 2010-10-02 05:26:00 2010-10-02 05:26:00 2010-10-02 05:26:00
# 23108 2010-09-21 09:56:00 2010-09-21 09:56:00 2010-09-21 09:56:00
# 23109 2010-04-29 04:30:00 2010-04-29 04:30:00 2010-04-29 04:30:00
# 23110 2010-03-16 19:58:00 2010-03-16 19:58:00 2010-03-16 19:58:00
#
# [23111 rows x 3 columns]

# %% [markdown]
# Вариант 3

# %%
taxi = pd.read_csv('C:/Users/artyr/Desktop/Karpov_ML/taxi_peru.csv', 
                   parse_dates=['start_at', 'end_at', 'arrived_at'], sep=';')

# %%
taxi.dtypes
# Out:
# journey_id                  object
# user_id                     object
# driver_id                   object
# taxi_id                     object
# icon                        object
# start_type                  object
# start_at            datetime64[ns]
# start_lat                   object
# start_lon                   object
# end_at              datetime64[ns]
# end_lat                     object
# end_lon                     object
# end_state                   object
# driver_start_lat            object
# driver_start_lon            object
# arrived_at          datetime64[ns]
# source                      object
# driver_score               float64
# rider_score                float64
# dtype: object

# %%
taxi.query('start_type == "asap" or start_type == "reserved"')
# Out:
#                              journey_id                           user_id  \
# 0      23a1406fc6a11d866e3c82f22eed4d4c  0e9af5bbf1edfe591b54ecdfd7e91e26
# 1      dd2af4715d0dc16eded53afc0e243577  a553c46e3a22fb9c326aeb3d72b3334e
# 2      dd91e131888064bf7df3ce08f3d4b4ad  a553c46e3a22fb9c326aeb3d72b3334e
# 3      dd2af4715d0dc16eded53afc0e2466d0  a553c46e3a22fb9c326aeb3d72b3334e
# 4      85b7eabcf5d84e42dc7629b7d27781af  56772d544fdfa589a020a1ff894a86f7
# ...                                 ...                               ...
# 23106  4a18ea5737ce0ffecaf20b305a0e2c86  8998bb370b5f0cec43a373adebba0c72
# 23107  f1e4317f2c17991dd90d1cd17ae0d399  5f8a6ffef0ea5df78a8ee890267b60ec
# 23108  1e44c0fd0a266c3719ff30410b257bce  c0ffb6f6cd801004dd8609c12277c2d1
# 23109  7073883383b89ad289e864022150cdd7  c0ffb6f6cd801004dd8609c12277c2d1
# 23110  b7dea45c3cc92b9efd5a4905e69ff9bf  c0ffb6f6cd801004dd8609c12277c2d1
#
#                               driver_id                           taxi_id  \
# ...

# %% [markdown]
# 9. Создайте колонку wait_time, в которой будет храниться разница между временем подачи машины (arrived_at) и временем заказа (start_at) в минутах. Чтобы сконвертировать полученный результат в минуты, можно использовать метод  .astype('timedelta64[m]')

# %%
taxi['wait_time'] = (taxi.arrived_at - taxi.start_at).astype('timedelta64[m]')

# %%
taxi
# Out:
#                              journey_id                           user_id  \
# 0      23a1406fc6a11d866e3c82f22eed4d4c  0e9af5bbf1edfe591b54ecdfd7e91e26
# 1      dd2af4715d0dc16eded53afc0e243577  a553c46e3a22fb9c326aeb3d72b3334e
# 2      dd91e131888064bf7df3ce08f3d4b4ad  a553c46e3a22fb9c326aeb3d72b3334e
# 3      dd2af4715d0dc16eded53afc0e2466d0  a553c46e3a22fb9c326aeb3d72b3334e
# 4      85b7eabcf5d84e42dc7629b7d27781af  56772d544fdfa589a020a1ff894a86f7
# ...                                 ...                               ...
# 23106  4a18ea5737ce0ffecaf20b305a0e2c86  8998bb370b5f0cec43a373adebba0c72
# 23107  f1e4317f2c17991dd90d1cd17ae0d399  5f8a6ffef0ea5df78a8ee890267b60ec
# 23108  1e44c0fd0a266c3719ff30410b257bce  c0ffb6f6cd801004dd8609c12277c2d1
# 23109  7073883383b89ad289e864022150cdd7  c0ffb6f6cd801004dd8609c12277c2d1
# 23110  b7dea45c3cc92b9efd5a4905e69ff9bf  c0ffb6f6cd801004dd8609c12277c2d1
#
#                               driver_id                           taxi_id  \
# ...

# %% [markdown]
# 10. Посмотрим, какие водители опаздывали на заказы к определенному времени (start_type == 'reserved'). Опозданием считается время ожидания wait_time > 0.0. Сгруппируйте отфильтрованные данные по driver_id и в качестве ответа укажите id водителя, который опоздал на заказ интересующего нас типа наибольшее число раз

# %%
taxi.query('start_type == "reserved" and wait_time > 0') \
    .groupby('driver_id') \
    .aggregate({'user_id': 'count'}) \
    .rename(columns={'user_id': 'late_number'}) \
    .idxmax()
# Out:
# late_number    406921adcca37705ef527b4246c0cfea
# dtype: object

# %% [markdown]
# Способ 2

# %%
taxi.query('start_type == "reserved" and wait_time > 0') \
    .driver_id \
    .value_counts() \
    .idxmax()
# Out:
# '406921adcca37705ef527b4246c0cfea'

# %% [markdown]
# 10. Добавьте столбец month, где будет храниться месяц, в котором был сделан заказ (start_at), как номер, и столбец weekday – название дня недели.

# %%
taxi['month'] = taxi.start_at.dt.month
taxi['weekday'] = taxi.start_at.dt.strftime('%A')

# %%
taxi
# Out:
#                              journey_id                           user_id  \
# 0      23a1406fc6a11d866e3c82f22eed4d4c  0e9af5bbf1edfe591b54ecdfd7e91e26
# 1      dd2af4715d0dc16eded53afc0e243577  a553c46e3a22fb9c326aeb3d72b3334e
# 2      dd91e131888064bf7df3ce08f3d4b4ad  a553c46e3a22fb9c326aeb3d72b3334e
# 3      dd2af4715d0dc16eded53afc0e2466d0  a553c46e3a22fb9c326aeb3d72b3334e
# 4      85b7eabcf5d84e42dc7629b7d27781af  56772d544fdfa589a020a1ff894a86f7
# ...                                 ...                               ...
# 23106  4a18ea5737ce0ffecaf20b305a0e2c86  8998bb370b5f0cec43a373adebba0c72
# 23107  f1e4317f2c17991dd90d1cd17ae0d399  5f8a6ffef0ea5df78a8ee890267b60ec
# 23108  1e44c0fd0a266c3719ff30410b257bce  c0ffb6f6cd801004dd8609c12277c2d1
# 23109  7073883383b89ad289e864022150cdd7  c0ffb6f6cd801004dd8609c12277c2d1
# 23110  b7dea45c3cc92b9efd5a4905e69ff9bf  c0ffb6f6cd801004dd8609c12277c2d1
#
#                               driver_id                           taxi_id  \
# ...

# %% [markdown]
# 12. Постройте график числа заказов по месяцам (month). В каком летнем месяце было сделано наименьшее число заказов? В качестве ответа введите номер месяца (6, 7 или 8).

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=[12, 8])
sns.countplot(taxi.month)
sns.despine()
# Out:
# D:\Programs\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# В июле было наименьшее число заказов

# %% [markdown]
# 13. А теперь – график по дням недели (weekday). Задать порядок столбиков на графике можно с помощью аргумента order, которому нужно передать список названий в нужном порядке. Вопрос: в какой день недели суммарно поступило меньше всего заказов?

# %%
plt.figure(figsize=[10, 6.5])
sns.countplot('weekday',
             data=taxi,
             order=['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'],
             hue='start_type',
             palette=['#15ed0f', '#10cc95'])
sns.despine()
# Out:
# D:\Programs\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Меньше всего заказов было в среду

# %% [markdown]
# 14. Также мы можем посмотреть на несколько простых метрик, показывающих число уникальных пользователей за определённый период:
# - DAU (daily active users) – число уникальных пользователей за день
# - WAU (weekly active users) – число уникальных пользователей за неделю
# - MAU (monthly active users) – число уникальных пользователей за месяц
# - Активные пользователи – те, кто воспользовался приложением и сделал хотя бы один заказ за выбранный промежуток времени.
# Постройте график MAU.

# %%
mau = taxi.groupby('month') \
    .aggregate({'user_id': 'nunique'})

# %%
xticks = range(1, 13)

# %%
plt.figure(figsize=[10, 6.5])
sns.lineplot(data=mau, markers='o')
plt.xticks(xticks);

# mau.plot(figsize=[12, 8])
