# %% [markdown]
# ### Step 2

# %%
import pandas as pd
import numpy as np

# %%
students_performance = pd.read_csv('../data/StudentsPerformance.csv')

# %%
students_performance.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
students_performance.gender.head()
# Out:
# 0    female
# 1    female
# 2    female
# 3      male
# 4      male
# Name: gender, dtype: object

# %%
students_performance.gender == 'female'
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 995     True
# 996    False
# 997     True
# 998     True
# 999     True
# Name: gender, Length: 1000, dtype: bool

# %%
students_performance.loc[students_performance.gender == 'female']
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
students_performance.loc[students_performance.gender == 'female', ['gender', 'writing score']]
# Out:
#      gender  writing score
# 0    female             74
# 1    female             88
# 2    female             93
# 5    female             78
# 6    female             92
# ..      ...            ...
# 993  female             74
# 995  female             95
# 997  female             65
# 998  female             77
# 999  female             86
#
# [518 rows x 2 columns]

# %% [markdown]
# ### Step 3

# %%
students_performance['writing score'].mean()
# Out:
# 68.054

# %%
mean_writing_score = students_performance['writing score'].mean()

# %%
students_performance.loc[students_performance['writing score'] > mean_writing_score]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# ..      ...            ...                         ...           ...
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# ### Step 5

# %%
students_performance.loc[(students_performance['writing score'] > mean_writing_score) & (students_performance.gender == 'female')]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
query = ((students_performance['writing score'] > mean_writing_score) & (students_performance.gender == 'female'))

# %%
students_performance.loc[query]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# #### Задача (step 6)
#
# У какой доли студентов из датасета **_StudentsPerformance.csv_** в колонке **lunch** указано _free/reduced_?
#
# Формат ответа - десятичная дробь, например, 0.25

# %%
students_performance.loc[students_performance['lunch'] == 'free/reduced', ['lunch']].size / len(students_performance)
# Out:
# 0.355

# %%
students_performance['lunch'].str.contains('free/reduced').mean()
# Out:
# 0.355

# %%
(students_performance['lunch'] == 'free/reduced').mean()
# Out:
# 0.355

# %% [markdown]
# #### Задача (step 7)

# %% [markdown]
# Как различается среднее и дисперсия оценок по предметам у групп студентов со стандартным или урезанным ланчем из  из датасета **_StudentsPerformance.csv_** ?

# %%
students_performance[(students_performance['lunch'] == 'free/reduced')].mean()
# Out:
# math score       58.921127
# reading score    64.653521
# writing score    63.022535
# dtype: float64

# %%
students_performance[(students_performance['lunch'] == 'standard')].mean()
# Out:
# math score       70.034109
# reading score    71.654264
# writing score    70.823256
# dtype: float64

# %%
students_performance[(students_performance['lunch'] == 'free/reduced')].var()
# Out:
# math score       229.824270
# reading score    221.871139
# writing score    238.202881
# dtype: float64

# %%
students_performance[(students_performance['lunch'] == 'standard')].var()
# Out:
# math score       186.418089
# reading score    191.285560
# writing score    205.620887
# dtype: float64

# %% [markdown]
# ### Step 8

# %%
students_performance = students_performance.rename(columns=\
                    {'parental level of education' : "parental_level_of_education",
                     'test preparation course' : "test_preparation_course",
                     'math score' : "math_score",
                     'reading score' : "reading_score",
                     'writing score' : "writing_score"})

# %%
students_performance.head()
# Out:
#    gender race/ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
students_performance.math_score.head()
# Out:
# 0    72
# 1    69
# 2    90
# 3    47
# 4    76
# Name: math_score, dtype: int64

# %%
students_performance.query("writing_score > 74")
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 991  female        group B            some high school      standard
# 992  female        group D          associate's degree  free/reduced
# 995  female        group E             master's degree      standard
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
students_performance.query("gender == 'female'")
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
students_performance.query("gender == 'female' & writing_score > 78")
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 6    female        group B                some college      standard
# 36   female        group D          associate's degree      standard
# 38   female        group D          associate's degree  free/reduced
# ..      ...            ...                         ...           ...
# 983  female        group A                some college      standard
# 984  female        group C            some high school      standard
# 989  female        group D                some college  free/reduced
# 995  female        group E             master's degree      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
writing_score_query = 80

# %%
students_performance.query("writing_score > @writing_score_query")
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 6    female        group B                some college      standard
# 16     male        group C                 high school      standard
# 34     male        group E                some college      standard
# ..      ...            ...                         ...           ...
# 983  female        group A                some college      standard
# 984  female        group C            some high school      standard
# 989  female        group D                some college  free/reduced
# 995  female        group E             master's degree      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %% [markdown]
# #### Задача (step 9)

# %%
student_stats = students_performance

# %%
student_stats[student_stats['parental_level_of_education'].isin(["bachelor's degree", "master's degree"])]
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 2    female        group B             master's degree      standard
# 14   female        group A             master's degree      standard
# 18     male        group C             master's degree  free/reduced
# 24     male        group D           bachelor's degree  free/reduced
# ..      ...            ...                         ...           ...
# 957  female        group D             master's degree      standard
# 969  female        group B           bachelor's degree      standard
# 970  female        group D           bachelor's degree      standard
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
student_stats[(student_stats['math_score'] > 80) & (student_stats['reading_score'] <= 72)]
# Out:
#     gender race/ethnicity parental_level_of_education     lunch  \
# 206   male        group E           bachelor's degree  standard
# 317   male        group C          associate's degree  standard
# 538   male        group E           bachelor's degree  standard
# 669   male        group D          associate's degree  standard
# 738   male        group D          associate's degree  standard
# 853   male        group E            some high school  standard
# 942   male        group C                 high school  standard
#
#     test_preparation_course  math_score  reading_score  writing_score
# 206                    none          82             62             62
# 317                    none          83             72             78
# 538               completed          85             66             71
# 669               completed          81             72             77
# 738                    none          81             71             73
# ...

# %%
student_stats[student_stats['test_preparation_course'] != 'completed']
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# ..      ...            ...                         ...           ...
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 994    male        group A                 high school      standard
# 996    male        group C                 high school  free/reduced
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
student_stats.query("lunch == 'standard'")
# Out:
#      gender race/ethnicity parental_level_of_education     lunch  \
# 0    female        group B           bachelor's degree  standard
# 1    female        group C                some college  standard
# 2    female        group B             master's degree  standard
# 4      male        group C                some college  standard
# 5    female        group B          associate's degree  standard
# ..      ...            ...                         ...       ...
# 987    male        group E            some high school  standard
# 991  female        group B            some high school  standard
# 994    male        group A                 high school  standard
# 995  female        group E             master's degree  standard
# 998  female        group D                some college  standard
#
#     test_preparation_course  math_score  reading_score  writing_score
# 0                      none          72             72             74
# ...

# %% [markdown]
# ### Step 10

# %%
students_performance[['math_score', 'reading_score']].head()
# Out:
#    math_score  reading_score
# 0          72             72
# 1          69             90
# 2          90             95
# 3          47             57
# 4          76             78

# %%
score_columns = [i for i in list(students_performance) if 'score' in i]

# %%
students_performance[score_columns].head()
# Out:
#    math_score  reading_score  writing_score
# 0          72             72             74
# 1          69             90             88
# 2          90             95             93
# 3          47             57             44
# 4          76             78             75

# %%
students_performance.filter(like='score')
# Out:
#      math_score  reading_score  writing_score
# 0            72             72             74
# 1            69             90             88
# 2            90             95             93
# 3            47             57             44
# 4            76             78             75
# ..          ...            ...            ...
# 995          88             99             95
# 996          62             55             55
# 997          59             71             65
# 998          68             78             77
# 999          77             86             86
#
# [1000 rows x 3 columns]

# %%
students_performance_with_names = students_performance.iloc[0:5]

# %%
students_performance_with_names.index = ["Cersei", "Tywin", "Gregor", "Joffrey", "Ilyn Payne"]

# %%
students_performance_with_names
# Out:
#             gender race/ethnicity parental_level_of_education         lunch  \
# Cersei      female        group B           bachelor's degree      standard
# Tywin       female        group C                some college      standard
# Gregor      female        group B             master's degree      standard
# Joffrey       male        group A          associate's degree  free/reduced
# Ilyn Payne    male        group C                some college      standard
#
#            test_preparation_course  math_score  reading_score  writing_score
# Cersei                        none          72             72             74
# Tywin                    completed          69             90             88
# Gregor                        none          90             95             93
# Joffrey                       none          47             57             44
# Ilyn Payne                    none          76             78             75

# %%
students_performance_with_names.filter(like='y', axis=0)
# Out:
#             gender race/ethnicity parental_level_of_education         lunch  \
# Tywin       female        group C                some college      standard
# Joffrey       male        group A          associate's degree  free/reduced
# Ilyn Payne    male        group C                some college      standard
#
#            test_preparation_course  math_score  reading_score  writing_score
# Tywin                    completed          69             90             88
# Joffrey                       none          47             57             44
# Ilyn Payne                    none          76             78             75
